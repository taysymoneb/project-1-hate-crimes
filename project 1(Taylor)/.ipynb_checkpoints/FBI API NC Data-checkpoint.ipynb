# %% [markdown]
# 3.What are the trends for hate crime incident reportings in the US and NC from 2016-2022?
#
# Between 2016 and 2022, there has been a definite increase in hate crime occurrences both nationally and locally in North Carolina. However, the number of incidents reported in North Carolina decreased by 15% from 2018 to 2019. After that, there was a drastic 65% increase in hate crimes reported. Nationally, there was a 9% increase in hate crime incidents from 2018 to 2019, followed by a 26% increase between 2019 and 2020.

# %%
# Dependencies and Setup
import requests
import pandas as pd
import json
from pprint import pprint
import matplotlib.pyplot as plt

#import api key from py file
from api_key import fbi_api_key

# %%
#build url
url = f"https://api.usa.gov/crime/fbi/cde/hate-crime/state/NC/count/all?from=1991&to=2020&API_KEY={fbi_api_key}"
#jsonify response
response = requests.get(url).json()
response
# Out:
# {'keys': ['Incident Count', 'Offense Count'],
#  'data': [{'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 1993,
#    'offense': 'all',
#    'incident_count': '10',
#    'offense_count': '13'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2014,
#    'offense': 'all',
#    'incident_count': '140',
#    'offense_count': '155'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2019,
#    'offense': 'all',
#    'incident_count': '232',
#    'offense_count': '242'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2005,
#    'offense': 'all',
#    'incident_count': '89',
#    'offense_count': '93'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2017,
#    'offense': 'all',
#    'incident_count': '166',
#    'offense_count': '191'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 1992,
#    'offense': 'all',
#    'incident_count': '1',
#    'offense_count': '1'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2010,
#    'offense': 'all',
#    'incident_count': '94',
#    'offense_count': '104'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2004,
#    'offense': 'all',
#    'incident_count': '67',
#    'offense_count': '73'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2006,
#    'offense': 'all',
#    'incident_count': '100',
#    'offense_count': '107'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2011,
#    'offense': 'all',
#    'incident_count': '112',
#    'offense_count': '118'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 1995,
#    'offense': 'all',
#    'incident_count': '52',
#    'offense_count': '58'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2013,
#    'offense': 'all',
#    'incident_count': '118',
#    'offense_count': '123'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2018,
#    'offense': 'all',
#    'incident_count': '140',
#    'offense_count': '167'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2008,
#    'offense': 'all',
#    'incident_count': '124',
#    'offense_count': '139'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2016,
#    'offense': 'all',
#    'incident_count': '148',
#    'offense_count': '177'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2009,
#    'offense': 'all',
#    'incident_count': '103',
#    'offense_count': '106'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 1996,
#    'offense': 'all',
#    'incident_count': '34',
#    'offense_count': '38'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 1998,
#    'offense': 'all',
#    'incident_count': '39',
#    'offense_count': '44'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2003,
#    'offense': 'all',
#    'incident_count': '77',
#    'offense_count': '88'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2007,
#    'offense': 'all',
#    'incident_count': '75',
#    'offense_count': '79'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 1997,
#    'offense': 'all',
#    'incident_count': '42',
#    'offense_count': '49'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2020,
#    'offense': 'all',
#    'incident_count': '287',
#    'offense_count': '306'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2001,
#    'offense': 'all',
#    'incident_count': '84',
#    'offense_count': '89'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2002,
#    'offense': 'all',
#    'incident_count': '62',
#    'offense_count': '65'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2000,
#    'offense': 'all',
#    'incident_count': '39',
#    'offense_count': '44'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2015,
#    'offense': 'all',
#    'incident_count': '161',
#    'offense_count': '177'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 1994,
#    'offense': 'all',
#    'incident_count': '7',
#    'offense_count': '7'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 2012,
#    'offense': 'all',
#    'incident_count': '119',
#    'offense_count': '126'},
#   {'state_id': 32,
#    'state_abbr': 'NC',
#    'data_year': 1999,
#    'offense': 'all',
#    'incident_count': '31',
#    'offense_count': '31'}]}

# %%
#create empty list to hold information to create a new data frame
years = []
incident_counts = []

#loop through the data to get information
for num in range(len(response["data"])):
    #print(response["data"][num])
    years.append(response["data"][num]["data_year"])
    incident_counts.append(response["data"][num]["incident_count"])
    
#create dataframe
incidentDF = pd.DataFrame({"Year":years, "Number of Incidents": incident_counts})
incidentDF = incidentDF.sort_values(by=["Year"])
incidentDF = incidentDF.reset_index(drop=True)
incidentDF
# Out:
#     Year Number of Incidents
# 0   1992                   1
# 1   1993                  10
# 2   1994                   7
# 3   1995                  52
# 4   1996                  34
# 5   1997                  42
# 6   1998                  39
# 7   1999                  31
# 8   2000                  39
# 9   2001                  84
# 10  2002                  62
# 11  2003                  77
# 12  2004                  67
# 13  2005                  89
# 14  2006                 100
# 15  2007                  75
# 16  2008                 124
# 17  2009                 103
# 18  2010                  94
# 19  2011                 112
# 20  2012                 119
# 21  2013                 118
# 22  2014                 140
# 23  2015                 161
# 24  2016                 148
# 25  2017                 166
# 26  2018                 140
# 27  2019                 232
# 28  2020                 287

# %%
#create a line graph displaying the years and incident counts
x = ["2016", "2017", "2018", "2019", "2020"]
y = [148, 166, 140, 232, 287]


plt.plot(x,y, marker="*", mfc = "gold", mec= "black", mew= "0.7", color= "black", markersize= 10)
plt.title ("Hate Crime Trend in NC (2016-2020)")
plt.xlabel("Years")
plt.ylabel("Number of Incidents")
plt.savefig("output_data/Fig9.png")
plt.show()

# %%
#calculate percent change
price_series = pd.Series(y)
price_series.pct_change()
# Out:
# 0         NaN
# 1    0.121622
# 2   -0.156627
# 3    0.657143
# 4    0.237069
# dtype: float64
