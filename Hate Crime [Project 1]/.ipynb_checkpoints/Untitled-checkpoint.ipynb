# %%
import pandas as pd
from pathlib import Path

# %%
csv_path = Path("Untitled Folder/hate_crime.csv")
Hate_crime_data_df = pd.read_csv(csv_path)
Hate_crime_data_df.head()
# Out:
#    incident_id  data_year        ori    pug_agency_name pub_agency_unit  \
# 0           43       1991  AR0350100         Pine Bluff             NaN
# 1           44       1991  AR0350100         Pine Bluff             NaN
# 2           45       1991  AR0600300  North Little Rock             NaN
# 3           46       1991  AR0600300  North Little Rock             NaN
# 4           47       1991  AR0670000             Sevier             NaN
#
#   agency_type_name state_abbr state_name       division_name region_name  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4           County         AR   Arkansas  West South Central       South  ...
#
#                offender_race offender_ethnicity victim_count  \
# ...

# %%
Hate_crime_data_df.columns
# Out:
# Index(['incident_id', 'data_year', 'ori', 'pug_agency_name', 'pub_agency_unit',
#        'agency_type_name', 'state_abbr', 'state_name', 'division_name',
#        'region_name', 'population_group_code', 'population_group_description',
#        'incident_date', 'adult_victim_count', 'juvenile_victim_count',
#        'total_offender_count', 'adult_offender_count',
#        'juvenile_offender_count', 'offender_race', 'offender_ethnicity',
#        'victim_count', 'offense_name', 'total_individual_victims',
#        'location_name', 'bias_desc', 'victim_types', 'multiple_offense',
#        'multiple_bias'],
#       dtype='object')

# %%
Hate_crime_data_df = Hate_crime_data_df[['incident_id', 'pug_agency_name','agency_type_name', 'state_abbr', 'state_name', 'division_name',
       'region_name', 'victim_count','location_name',]]
Hate_crime_data_df.head()
# Out:
#    incident_id    pug_agency_name agency_type_name state_abbr state_name  \
# 0           43         Pine Bluff             City         AR   Arkansas
# 1           44         Pine Bluff             City         AR   Arkansas
# 2           45  North Little Rock             City         AR   Arkansas
# 3           46  North Little Rock             City         AR   Arkansas
# 4           47             Sevier           County         AR   Arkansas
#
#         division_name region_name  victim_count  \
# 0  West South Central       South             1
# 1  West South Central       South             2
# 2  West South Central       South             2
# 3  West South Central       South             1
# 4  West South Central       South             1
#
#                         location_name
# 0                      Residence/Home
# 1  Highway/Road/Alley/Street/Sidewalk
# 2                      Residence/Home
# 3                      Residence/Home
# 4                      School/College

# %%
States_crime_count_sorted = States_crime_count.sort_values(ascending=False)
States_crime_count_sorted
# Out:
# state_name
# California              50899
# New Jersey              24457
# New York                24029
# Michigan                15705
# Massachusetts           14564
# Washington              13036
# Ohio                    12232
# Texas                   11989
# Arizona                  9531
# Illinois                 7733
# Virginia                 7263
# Maryland                 7051
# Colorado                 6686
# Florida                  6557
# Minnesota                6487
# Oregon                   6390
# Tennessee                5405
# Pennsylvania             5272
# Connecticut              5082
# Missouri                 5074
# Kentucky                 4823
# North Carolina           4515
# Indiana                  3309
# South Carolina           2801
# Nevada                   2707
# Kansas                   2666
# Nebraska                 2457
# Utah                     2433
# Wisconsin                2366
# Georgia                  2301
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(10, 6))
States_crime_count_sorted.plot(kind='bar')
plt.title('Total Number of Victims by State')
plt.xlabel('State')
plt.ylabel('Number of Victims')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
Hate_crime_data_df.head()
# Out:
#    incident_id    pug_agency_name agency_type_name state_abbr state_name  \
# 0           43         Pine Bluff             City         AR   Arkansas
# 1           44         Pine Bluff             City         AR   Arkansas
# 2           45  North Little Rock             City         AR   Arkansas
# 3           46  North Little Rock             City         AR   Arkansas
# 4           47             Sevier           County         AR   Arkansas
#
#         division_name region_name  victim_count  \
# 0  West South Central       South             1
# 1  West South Central       South             2
# 2  West South Central       South             2
# 3  West South Central       South             1
# 4  West South Central       South             1
#
#                         location_name
# 0                      Residence/Home
# 1  Highway/Road/Alley/Street/Sidewalk
# 2                      Residence/Home
# 3                      Residence/Home
# 4                      School/College

# %%
Hatecrime_locations = Hate_crime_data_df.groupby('location_name')['victim_count'].sum().reset_index()
Hatecrime_locations.tail()
# Out:
#                 location_name  victim_count
# 144       Service/Gas Station          2788
# 145  Shelter-Mission/Homeless           191
# 146             Shopping Mall           334
# 147           Specialty Store          3261
# 148              Tribal Lands            26

# %%
location_victim_count= Hatecrime_locations.sort_values(by='victim_count', ascending=False)
location_victim_count.head(10)
# Out:
#                           location_name  victim_count
# 133                      Residence/Home         90426
# 93   Highway/Road/Alley/Street/Sidewalk         57681
# 120                       Other/Unknown         35621
# 143                      School/College         20994
# 126             Parking/Drop Lot/Garage         17513
# 24       Church/Synagogue/Temple/Mosque         11013
# 140                          Restaurant          6576
# 32           Commercial/Office Building          6465
# 18                        Bar/Nightclub          5458
# 142         School-Elementary/Secondary          4627

# %%
Top_10locations = location_victim_count.head(10)
Top_10locations
# Out:
#                           location_name  victim_count
# 133                      Residence/Home         90426
# 93   Highway/Road/Alley/Street/Sidewalk         57681
# 120                       Other/Unknown         35621
# 143                      School/College         20994
# 126             Parking/Drop Lot/Garage         17513
# 24       Church/Synagogue/Temple/Mosque         11013
# 140                          Restaurant          6576
# 32           Commercial/Office Building          6465
# 18                        Bar/Nightclub          5458
# 142         School-Elementary/Secondary          4627

# %%
Location_visual = Top_10locations.set_index('location_name')
Location_visual
# Out:
#                                     victim_count
# location_name
# Residence/Home                             90426
# Highway/Road/Alley/Street/Sidewalk         57681
# Other/Unknown                              35621
# School/College                             20994
# Parking/Drop Lot/Garage                    17513
# Church/Synagogue/Temple/Mosque             11013
# Restaurant                                  6576
# Commercial/Office Building                  6465
# Bar/Nightclub                               5458
# School-Elementary/Secondary                 4627

# %%
pies = ['Residence/Home',
        'Highway/Road/Alley/Street/Sidewalk', 
        'Other/Unknown', 
        'School/College',
        'Parking/Drop Lot/Garage',
        'Church/Synagogue/Temple/Mosque',
        'Restaurant',
        'Commercial/Office Building',
        'Bar/Nightclub',
        'School-Elementary/Secondary']
pie_counts = [90426,57681,35621,20994,17513,11013,6576,6465,5458,4627]
plt.figure(figsize=(8, 8))
plt.pie(pie_counts, labels = pies, autopct='%1.1f%%')
plt.title('Victim count by location of incident')
plt.axis("equal")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
